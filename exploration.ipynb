# %% [markdown]
# # Analysis preview

# %% [markdown]
# This preview helps me know what kind of data I'm moving and how should I transform it

# %% [markdown]
# ## Variables, libraries, configs

# %%
import os
import requests
import sqlite3
import pandas as pd
from dotenv import load_dotenv
from datetime import datetime, timedelta
pd.set_option('display.max_columns', None)

# %%
#loading environment variables
load_dotenv() 

STATION_ID = os.getenv("STATION_ID", "KGPH")
API_BASE_URL = os.getenv("API_BASE_URL", "https://api.weather.gov")
USER_AGENT = os.getenv("USER_AGENT", "(example_weather_app, contact@example.com)")

# %%
# url for each endpoint
url_station = f"{API_BASE_URL}/stations/{STATION_ID}"
url_obs = f"{API_BASE_URL}/stations/{STATION_ID}/observations"

#extraction start date (last 7 days)
start_date = (datetime.now() - timedelta(days=7))
#start date format should be YYYY-MM-DDThh:mm:ssZ or YYYY-MM-DDThh:mm:ss+hh:mm
start_date_str = start_date.strftime("%Y-%m-%dT%H:%M:%SZ")

# %% [markdown]
# ## Extraction

# %% [markdown]
# ### Stations endpoint

# %%
headers = {"User-Agent": USER_AGENT}
station = requests.get(url_station, headers=headers).json()

# %%
station #should handle errors (if station not found, etc)
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#   {'@version': '1.1',
#    'wx': 'https://api.weather.gov/ontology#',
#    's': 'https://schema.org/',
#    'geo': 'http://www.opengis.net/ont/geosparql#',
#    'unit': 'http://codes.wmo.int/common/unit/',
#    '@vocab': 'https://api.weather.gov/ontology#',
#    'geometry': {'@id': 's:GeoCoordinates', '@type': 'geo:wktLiteral'},
#    'city': 's:addressLocality',
#    'state': 's:addressRegion',
#    'distance': {'@id': 's:Distance', '@type': 's:QuantitativeValue'},
#    'bearing': {'@type': 's:QuantitativeValue'},
#    'value': {'@id': 's:value'},
#    'unitCode': {'@id': 's:unitCode', '@type': '@id'},
#    'forecastOffice': {'@type': '@id'},
#    'forecastGridData': {'@type': '@id'},
#    'publicZone': {'@type': '@id'},
#    'county': {'@type': '@id'}}],
#  'id': 'https://api.weather.gov/stations/KGPH',
#  'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-94.3096, 39.3325]},
#  'properties': {'@id': 'https://api.weather.gov/stations/KGPH',
#   '@type': 'wx:ObservationStation',
#   'elevation': {'unitCode': 'wmoUnit:m', 'value': 236.8296},
#   'stationIdentifier': 'KGPH',
#   'name': 'Mosby Midwest National Air Center Airport',
#   'timeZone': 'America/Chicago',
#   'forecast': 'https://api.weather.gov/zones/forecast/MOZ029',
#   'county': 'https://api.weather.gov/zones/county/MOC047',
#   'fireWeatherZone': 'https://api.weather.gov/zones/fire/MOZ029'}}

# %%
# saving station  timezone
station_timezone = station['properties']['timeZone']

# %% [markdown]
# ### Observations endpoint

# %%
observations = requests.get(
    url_obs,
    headers=headers,
    params={"start": start_date_str}
).json()

# %%
observations
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#   {'@version': '1.1',
#    'wx': 'https://api.weather.gov/ontology#',
#    's': 'https://schema.org/',
#    'geo': 'http://www.opengis.net/ont/geosparql#',
#    'unit': 'http://codes.wmo.int/common/unit/',
#    '@vocab': 'https://api.weather.gov/ontology#',
#    'geometry': {'@id': 's:GeoCoordinates', '@type': 'geo:wktLiteral'},
#    'city': 's:addressLocality',
#    'state': 's:addressRegion',
#    'distance': {'@id': 's:Distance', '@type': 's:QuantitativeValue'},
#    'bearing': {'@type': 's:QuantitativeValue'},
#    'value': {'@id': 's:value'},
#    'unitCode': {'@id': 's:unitCode', '@type': '@id'},
#    'forecastOffice': {'@type': '@id'},
#    'forecastGridData': {'@type': '@id'},
#    'publicZone': {'@type': '@id'},
#    'county': {'@type': '@id'}}],
#  'type': 'FeatureCollection',
#  'features': [{'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T19:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T19:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T19:55:00+00:00',
#     'rawMessage': 'KGPH 071955Z AUTO 17004KT 10SM CLR 31/19 A3003 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 31,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 19,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 170,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 7.56,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101690,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 48.878892298939,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 32.399899398323335,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T18:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T18:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T18:55:00+00:00',
#     'rawMessage': 'KGPH 071855Z AUTO 17006KT 10SM SCT037 SCT080 31/21 A3004 RMK AO2',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 31,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 170,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 11.16,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101730,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 55.321861254559,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 33.73780565048222,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 1130},
#       'amount': 'SCT'},
#      {'base': {'unitCode': 'wmoUnit:m', 'value': 2440}, 'amount': 'SCT'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T17:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T17:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T17:55:00+00:00',
#     'rawMessage': 'KGPH 071755Z AUTO 00000KT 10SM SCT039 30/21 A3005 RMK AO2',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 30,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101760,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 58.581385103971,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 32.553350785335,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 1190},
#       'amount': 'SCT'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T15:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T15:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T15:35:00+00:00',
#     'rawMessage': 'KGPH 071535Z AUTO 10003KT 10SM CLR 28/21 A3005 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 28,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 100,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 5.4,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101760,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 65.771194518237,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 30.12559556856,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T14:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T14:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T14:55:00+00:00',
#     'rawMessage': 'KGPH 071455Z AUTO 00000KT 10SM CLR 28/21 A3005 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 28,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101760,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 65.771194518237,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 30.12559556856,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T14:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T14:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T14:35:00+00:00',
#     'rawMessage': 'KGPH 071435Z AUTO 00000KT 10SM CLR 28/21 A3005 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 28,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101760,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 65.771194518237,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 30.12559556856,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T14:15:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T14:15:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T14:15:00+00:00',
#     'rawMessage': 'KGPH 071415Z AUTO 00000KT 10SM CLR 27/21 A3005 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 27,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101760,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 69.735359877774,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 28.833639714513332,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T13:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T13:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T13:35:00+00:00',
#     'rawMessage': 'KGPH 071335Z AUTO 00000KT 10SM CLR 25/21 A3004 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 25,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101730,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 78.497647216551,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 25.605216343987777,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T13:15:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T13:15:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T13:15:00+00:00',
#     'rawMessage': 'KGPH 071315Z AUTO 00000KT 10SM CLR 24/21 A3003 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 24,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101690,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 83.338787521304,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 24.631623896389446,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T12:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T12:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T12:35:00+00:00',
#     'rawMessage': 'KGPH 071235Z AUTO 00000KT 10SM CLR 22/21 A3002 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 22,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101660,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 94.06252427588,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 22.711632578314443,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T12:15:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T12:15:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T12:15:00+00:00',
#     'rawMessage': '',
#     'textDescription': '',
#     'icon': None,
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101660,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 100,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'cloudLayers': []}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T11:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T11:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T11:55:00+00:00',
#     'rawMessage': 'KGPH 071155Z AUTO 00000KT 10SM CLR 20/20 A3002 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 20,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 20,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101660,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 100,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T09:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T09:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T09:35:00+00:00',
#     'rawMessage': '',
#     'textDescription': '',
#     'icon': None,
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 20,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101560,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 94.018757001038,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'cloudLayers': []}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T07:15:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T07:15:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T07:15:00+00:00',
#     'rawMessage': 'KGPH 070715Z AUTO 00000KT 10SM CLR 21/21 A3000 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101590,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 100,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T06:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T06:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T06:35:00+00:00',
#     'rawMessage': 'KGPH 070635Z AUTO 00000KT 10SM CLR 21/21 A2999 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101560,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 100,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T05:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T05:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T05:35:00+00:00',
#     'rawMessage': 'KGPH 070535Z AUTO 00000KT 10SM CLR 22/21 A3000 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 22,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101590,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 94.06252427588,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 22.711632578314443,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T05:15:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T05:15:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T05:15:00+00:00',
#     'rawMessage': '',
#     'textDescription': '',
#     'icon': None,
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 22,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101590,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 94.06252427588,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 22.711632578314443,
#      'qualityControl': 'V'},
#     'cloudLayers': []}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T04:15:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T04:15:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T04:15:00+00:00',
#     'rawMessage': 'KGPH 070415Z AUTO 00000KT 10SM CLR 23/21 A2999 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 23,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101560,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 88.518307938961,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 23.666866929517223,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T03:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T03:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T03:55:00+00:00',
#     'rawMessage': 'KGPH 070355Z AUTO 00000KT 10SM CLR 23/21 A2999 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 23,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101560,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 88.518307938961,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 23.666866929517223,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T02:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T02:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T02:55:00+00:00',
#     'rawMessage': 'KGPH 070255Z AUTO 00000KT 10SM CLR 25/21 A2997 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 25,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
# ...
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 78.354092127266,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 24.50146796110111,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 2740},
#       'amount': 'BKN'},
#      {'base': {'unitCode': 'wmoUnit:m', 'value': 3350}, 'amount': 'BKN'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T22:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T22:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-06-30T22:55:00+00:00',
#     'rawMessage': 'KGPH 302255Z AUTO 00000KT 10SM SCT085 BKN120 25/20 A2999 RMK AO2',
#     'textDescription': 'Mostly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/day/bkn?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 25,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 20,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101560,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 73.802512188061,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 25.482621151577224,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 2590},
#       'amount': 'SCT'},
#      {'base': {'unitCode': 'wmoUnit:m', 'value': 3660}, 'amount': 'BKN'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T22:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T22:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-06-30T22:35:00+00:00',
#     'rawMessage': 'KGPH 302235Z AUTO 36003KT 10SM SCT085 SCT110 24/20 A3000 RMK AO2',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 24,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 20,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 360,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 5.4,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101590,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 78.354092127266,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 24.50146796110111,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 2590},
#       'amount': 'SCT'},
#      {'base': {'unitCode': 'wmoUnit:m', 'value': 3350}, 'amount': 'SCT'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T22:15:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T22:15:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-06-30T22:15:00+00:00',
#     'rawMessage': 'KGPH 302215Z AUTO 36003KT 10SM SCT120 23/19 A3000 RMK AO2',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 23,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 19,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 360,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 5.4,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101590,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 78.209169794993,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 23.397683877980555,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 3660},
#       'amount': 'SCT'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T21:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T21:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-06-30T21:55:00+00:00',
#     'rawMessage': 'KGPH 302155Z AUTO 34005KT 10SM SCT120 23/19 A2999 RMK AO2',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 23,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 19,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 340,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 9.36,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101560,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 78.209169794993,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 23.397683877980555,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 3660},
#       'amount': 'SCT'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T21:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T21:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-06-30T21:35:00+00:00',
#     'rawMessage': 'KGPH 302135Z AUTO 35004KT 10SM SCT070 SCT090 SCT120 22/19 A2999 RMK AO2',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 22,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 19,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 350,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 7.56,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101560,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 83.107688157695,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 22.42558963522889,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 2130},
#       'amount': 'SCT'},
#      {'base': {'unitCode': 'wmoUnit:m', 'value': 2740}, 'amount': 'SCT'},
#      {'base': {'unitCode': 'wmoUnit:m', 'value': 3660}, 'amount': 'SCT'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T21:15:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T21:15:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-06-30T21:15:00+00:00',
#     'rawMessage': 'KGPH 302115Z AUTO 04004KT 10SM SCT023 SCT037 BKN060 22/20 A3000 RMK AO2',
#     'textDescription': 'Mostly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/day/bkn?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 22,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 20,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 40,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 7.56,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101590,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 88.436416127982,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 22.564728643341667,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 700},
#       'amount': 'SCT'},
#      {'base': {'unitCode': 'wmoUnit:m', 'value': 1130}, 'amount': 'SCT'},
#      {'base': {'unitCode': 'wmoUnit:m', 'value': 1830}, 'amount': 'BKN'}]}}]}

# %%
# loading the data into a pandas dataframe
df = pd.json_normalize(observations['features'])

# %%
df.head()
# Out:
#                                                   id     type geometry.type  \
# 0  https://api.weather.gov/stations/KGPH/observat...  Feature         Point
# 1  https://api.weather.gov/stations/KGPH/observat...  Feature         Point
# 2  https://api.weather.gov/stations/KGPH/observat...  Feature         Point
# 3  https://api.weather.gov/stations/KGPH/observat...  Feature         Point
# 4  https://api.weather.gov/stations/KGPH/observat...  Feature         Point
#
#   geometry.coordinates                                     properties.@id  \
# 0      [-94.31, 39.33]  https://api.weather.gov/stations/KGPH/observat...
# 1      [-94.31, 39.33]  https://api.weather.gov/stations/KGPH/observat...
# 2      [-94.31, 39.33]  https://api.weather.gov/stations/KGPH/observat...
# 3      [-94.31, 39.33]  https://api.weather.gov/stations/KGPH/observat...
# 4      [-94.31, 39.33]  https://api.weather.gov/stations/KGPH/observat...
#
#         properties.@type properties.elevation.unitCode  \
# 0  wx:ObservationStation                     wmoUnit:m
# 1  wx:ObservationStation                     wmoUnit:m
# 2  wx:ObservationStation                     wmoUnit:m
# 3  wx:ObservationStation                     wmoUnit:m
# 4  wx:ObservationStation                     wmoUnit:m
#
#    properties.elevation.value                     properties.station  \
# 0                         237  https://api.weather.gov/stations/KGPH
# 1                         237  https://api.weather.gov/stations/KGPH
# 2                         237  https://api.weather.gov/stations/KGPH
# 3                         237  https://api.weather.gov/stations/KGPH
# 4                         237  https://api.weather.gov/stations/KGPH
#
#   properties.stationId                     properties.stationName  \
# 0                 KGPH  Mosby Midwest National Air Center Airport
# 1                 KGPH  Mosby Midwest National Air Center Airport
# 2                 KGPH  Mosby Midwest National Air Center Airport
# 3                 KGPH  Mosby Midwest National Air Center Airport
# 4                 KGPH  Mosby Midwest National Air Center Airport
#
#         properties.timestamp  \
# 0  2025-07-07T19:55:00+00:00
# 1  2025-07-07T18:55:00+00:00
# 2  2025-07-07T17:55:00+00:00
# 3  2025-07-07T15:35:00+00:00
# 4  2025-07-07T14:55:00+00:00
#
#                                properties.rawMessage  \
# 0  KGPH 071955Z AUTO 17004KT 10SM CLR 31/19 A3003...
# 1  KGPH 071855Z AUTO 17006KT 10SM SCT037 SCT080 3...
# 2  KGPH 071755Z AUTO 00000KT 10SM SCT039 30/21 A3...
# 3  KGPH 071535Z AUTO 10003KT 10SM CLR 28/21 A3005...
# 4  KGPH 071455Z AUTO 00000KT 10SM CLR 28/21 A3005...
#
#   properties.textDescription  \
# 0                      Clear
# 1              Partly Cloudy
# 2              Partly Cloudy
# 3                      Clear
# 4                      Clear
#
#                                      properties.icon  \
# 0  https://api.weather.gov/icons/land/day/skc?siz...
# 1  https://api.weather.gov/icons/land/day/sct?siz...
# 2  https://api.weather.gov/icons/land/day/sct?siz...
# 3  https://api.weather.gov/icons/land/day/skc?siz...
# 4  https://api.weather.gov/icons/land/day/skc?siz...
#
#   properties.presentWeather properties.temperature.unitCode  \
# 0                        []                    wmoUnit:degC
# 1                        []                    wmoUnit:degC
# 2                        []                    wmoUnit:degC
# 3                        []                    wmoUnit:degC
# 4                        []                    wmoUnit:degC
#
#    properties.temperature.value properties.temperature.qualityControl  \
# 0                          31.0                                     V
# 1                          31.0                                     V
# 2                          30.0                                     V
# 3                          28.0                                     V
# 4                          28.0                                     V
#
#   properties.dewpoint.unitCode  properties.dewpoint.value  \
# 0                 wmoUnit:degC                       19.0
# 1                 wmoUnit:degC                       21.0
# 2                 wmoUnit:degC                       21.0
# 3                 wmoUnit:degC                       21.0
# 4                 wmoUnit:degC                       21.0
#
#   properties.dewpoint.qualityControl properties.windDirection.unitCode  \
# 0                                  V            wmoUnit:degree_(angle)
# 1                                  V            wmoUnit:degree_(angle)
# 2                                  V            wmoUnit:degree_(angle)
# 3                                  V            wmoUnit:degree_(angle)
# 4                                  V            wmoUnit:degree_(angle)
#
#    properties.windDirection.value properties.windDirection.qualityControl  \
# 0                           170.0                                       V
# 1                           170.0                                       V
# 2                             0.0                                       V
# 3                           100.0                                       V
# 4                             0.0                                       V
#
#   properties.windSpeed.unitCode  properties.windSpeed.value  \
# 0                wmoUnit:km_h-1                        7.56
# 1                wmoUnit:km_h-1                       11.16
# 2                wmoUnit:km_h-1                        0.00
# 3                wmoUnit:km_h-1                        5.40
# 4                wmoUnit:km_h-1                        0.00
#
#   properties.windSpeed.qualityControl properties.windGust.unitCode  \
# 0                                   V               wmoUnit:km_h-1
# 1                                   V               wmoUnit:km_h-1
# 2                                   V               wmoUnit:km_h-1
# 3                                   V               wmoUnit:km_h-1
# 4                                   V               wmoUnit:km_h-1
#
#   properties.windGust.value properties.windGust.qualityControl  \
# 0                      None                                  Z
# 1                      None                                  Z
# 2                      None                                  Z
# 3                      None                                  Z
# 4                      None                                  Z
#
#   properties.barometricPressure.unitCode  properties.barometricPressure.value  \
# 0                             wmoUnit:Pa                             101690.0
# 1                             wmoUnit:Pa                             101730.0
# 2                             wmoUnit:Pa                             101760.0
# 3                             wmoUnit:Pa                             101760.0
# 4                             wmoUnit:Pa                             101760.0
#
#   properties.barometricPressure.qualityControl  \
# 0                                            V
# 1                                            V
# 2                                            V
# 3                                            V
# 4                                            V
#
#   properties.seaLevelPressure.unitCode properties.seaLevelPressure.value  \
# 0                           wmoUnit:Pa                              None
# 1                           wmoUnit:Pa                              None
# 2                           wmoUnit:Pa                              None
# 3                           wmoUnit:Pa                              None
# 4                           wmoUnit:Pa                              None
#
#   properties.seaLevelPressure.qualityControl properties.visibility.unitCode  \
# 0                                          Z                      wmoUnit:m
# 1                                          Z                      wmoUnit:m
# 2                                          Z                      wmoUnit:m
# 3                                          Z                      wmoUnit:m
# 4                                          Z                      wmoUnit:m
#
#    properties.visibility.value properties.visibility.qualityControl  \
# 0                        16090                                    C
# 1                        16090                                    C
# 2                        16090                                    C
# 3                        16090                                    C
# 4                        16090                                    C
#
#   properties.maxTemperatureLast24Hours.unitCode  \
# 0                                  wmoUnit:degC
# 1                                  wmoUnit:degC
# 2                                  wmoUnit:degC
# 3                                  wmoUnit:degC
# 4                                  wmoUnit:degC
#
#   properties.maxTemperatureLast24Hours.value  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
#
#   properties.minTemperatureLast24Hours.unitCode  \
# 0                                  wmoUnit:degC
# 1                                  wmoUnit:degC
# 2                                  wmoUnit:degC
# 3                                  wmoUnit:degC
# 4                                  wmoUnit:degC
#
#   properties.minTemperatureLast24Hours.value  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
#
#   properties.precipitationLastHour.unitCode  \
# 0                                wmoUnit:mm
# 1                                wmoUnit:mm
# 2                                wmoUnit:mm
# 3                                wmoUnit:mm
# 4                                wmoUnit:mm
#
#    properties.precipitationLastHour.value  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   properties.precipitationLastHour.qualityControl  \
# 0                                               Z
# 1                                               Z
# 2                                               Z
# 3                                               Z
# 4                                               Z
#
#   properties.precipitationLast3Hours.unitCode  \
# 0                                  wmoUnit:mm
# 1                                  wmoUnit:mm
# 2                                  wmoUnit:mm
# 3                                  wmoUnit:mm
# 4                                  wmoUnit:mm
#
#   properties.precipitationLast3Hours.value  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
#
#   properties.precipitationLast3Hours.qualityControl  \
# 0                                                 Z
# 1                                                 Z
# 2                                                 Z
# 3                                                 Z
# 4                                                 Z
#
#   properties.precipitationLast6Hours.unitCode  \
# 0                                  wmoUnit:mm
# 1                                  wmoUnit:mm
# 2                                  wmoUnit:mm
# 3                                  wmoUnit:mm
# 4                                  wmoUnit:mm
#
#   properties.precipitationLast6Hours.value  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
#
#   properties.precipitationLast6Hours.qualityControl  \
# 0                                                 Z
# 1                                                 Z
# 2                                                 Z
# 3                                                 Z
# 4                                                 Z
#
#   properties.relativeHumidity.unitCode  properties.relativeHumidity.value  \
# 0                      wmoUnit:percent                          48.878892
# 1                      wmoUnit:percent                          55.321861
# 2                      wmoUnit:percent                          58.581385
# 3                      wmoUnit:percent                          65.771195
# 4                      wmoUnit:percent                          65.771195
#
#   properties.relativeHumidity.qualityControl properties.windChill.unitCode  \
# 0                                          V                  wmoUnit:degC
# 1                                          V                  wmoUnit:degC
# 2                                          V                  wmoUnit:degC
# 3                                          V                  wmoUnit:degC
# 4                                          V                  wmoUnit:degC
#
#   properties.windChill.value properties.windChill.qualityControl  \
# 0                       None                                   V
# 1                       None                                   V
# 2                       None                                   V
# 3                       None                                   V
# 4                       None                                   V
#
#   properties.heatIndex.unitCode  properties.heatIndex.value  \
# 0                  wmoUnit:degC                   32.399899
# 1                  wmoUnit:degC                   33.737806
# 2                  wmoUnit:degC                   32.553351
# 3                  wmoUnit:degC                   30.125596
# 4                  wmoUnit:degC                   30.125596
#
#   properties.heatIndex.qualityControl  \
# 0                                   V
# 1                                   V
# 2                                   V
# 3                                   V
# 4                                   V
#
#                               properties.cloudLayers
# 0  [{'base': {'unitCode': 'wmoUnit:m', 'value': N...
# 1  [{'base': {'unitCode': 'wmoUnit:m', 'value': 1...
# 2  [{'base': {'unitCode': 'wmoUnit:m', 'value': 1...
# 3  [{'base': {'unitCode': 'wmoUnit:m', 'value': N...
# 4  [{'base': {'unitCode': 'wmoUnit:m', 'value': N...

# %%
df.columns
# Out:
# Index(['id', 'type', 'geometry.type', 'geometry.coordinates', 'properties.@id',
#        'properties.@type', 'properties.elevation.unitCode',
#        'properties.elevation.value', 'properties.station',
#        'properties.stationId', 'properties.stationName',
#        'properties.timestamp', 'properties.rawMessage',
#        'properties.textDescription', 'properties.icon',
#        'properties.presentWeather', 'properties.temperature.unitCode',
#        'properties.temperature.value', 'properties.temperature.qualityControl',
#        'properties.dewpoint.unitCode', 'properties.dewpoint.value',
#        'properties.dewpoint.qualityControl',
#        'properties.windDirection.unitCode', 'properties.windDirection.value',
#        'properties.windDirection.qualityControl',
#        'properties.windSpeed.unitCode', 'properties.windSpeed.value',
#        'properties.windSpeed.qualityControl', 'properties.windGust.unitCode',
#        'properties.windGust.value', 'properties.windGust.qualityControl',
#        'properties.barometricPressure.unitCode',
#        'properties.barometricPressure.value',
#        'properties.barometricPressure.qualityControl',
#        'properties.seaLevelPressure.unitCode',
#        'properties.seaLevelPressure.value',
#        'properties.seaLevelPressure.qualityControl',
#        'properties.visibility.unitCode', 'properties.visibility.value',
#        'properties.visibility.qualityControl',
#        'properties.maxTemperatureLast24Hours.unitCode',
#        'properties.maxTemperatureLast24Hours.value',
#        'properties.minTemperatureLast24Hours.unitCode',
#        'properties.minTemperatureLast24Hours.value',
#        'properties.precipitationLastHour.unitCode',
#        'properties.precipitationLastHour.value',
#        'properties.precipitationLastHour.qualityControl',
#        'properties.precipitationLast3Hours.unitCode',
#        'properties.precipitationLast3Hours.value',
#        'properties.precipitationLast3Hours.qualityControl',
#        'properties.precipitationLast6Hours.unitCode',
#        'properties.precipitationLast6Hours.value',
#        'properties.precipitationLast6Hours.qualityControl',
#        'properties.relativeHumidity.unitCode',
#        'properties.relativeHumidity.value',
#        'properties.relativeHumidity.qualityControl',
#        'properties.windChill.unitCode', 'properties.windChill.value',
#        'properties.windChill.qualityControl', 'properties.heatIndex.unitCode',
#        'properties.heatIndex.value', 'properties.heatIndex.qualityControl',
#        'properties.cloudLayers'],
#       dtype='object')

# %%
# mapping the fields to the database schema
# station_id = properties.stationId
# station_name = properties.stationName
# station_timezone = missing - taking it from station metadata in station_timezone
# latitude/longitude = geometry.coordinates	
# observation timestamp = properties.timestamp
# temperature = properties.temperature.value
    # temperature unit = properties.temperature.unitCode
#wind speed = properties.windSpeed.value
    # wind speed unit = properties.windSpeed.unitCode
#humidity = properties.relativeHumidity.value

# %% [markdown]
# ## Cleaning

# %%
columns_needed = [
    'properties.stationId',
    'properties.stationName',
    'properties.timestamp',
    'properties.temperature.value',
    # 'properties.temperature.unitCode',
    'properties.windSpeed.value',
    # 'properties.windSpeed.unitCode',
    'properties.relativeHumidity.value',
    'geometry.coordinates'
]
#filtering columns
df_filtered = df[columns_needed]
#renaming columns to match the database schema
df_filtered.columns = [
    'station_id',
    'station_name',
    'timestamp',
    # 'temperature_value',
    'temperature_unit',
    # 'wind_speed_value',
    'wind_speed_unit',
    'humidity_value',
    'coordinates'
]

# %%
df_filtered.head()
# Out:
#   station_id                               station_name  \
# 0       KGPH  Mosby Midwest National Air Center Airport
# 1       KGPH  Mosby Midwest National Air Center Airport
# 2       KGPH  Mosby Midwest National Air Center Airport
# 3       KGPH  Mosby Midwest National Air Center Airport
# 4       KGPH  Mosby Midwest National Air Center Airport
#
#                    timestamp  temperature_unit  wind_speed_unit  \
# 0  2025-07-07T19:55:00+00:00              31.0             7.56
# 1  2025-07-07T18:55:00+00:00              31.0            11.16
# 2  2025-07-07T17:55:00+00:00              30.0             0.00
# 3  2025-07-07T15:35:00+00:00              28.0             5.40
# 4  2025-07-07T14:55:00+00:00              28.0             0.00
#
#    humidity_value      coordinates
# 0       48.878892  [-94.31, 39.33]
# 1       55.321861  [-94.31, 39.33]
# 2       58.581385  [-94.31, 39.33]
# 3       65.771195  [-94.31, 39.33]
# 4       65.771195  [-94.31, 39.33]

# %%
df_filtered['latitude'] = df_filtered['coordinates'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None)
df_filtered['longitude'] = df_filtered['coordinates'].apply(lambda x: x[1] if isinstance(x, list) and len(x) > 1 else None)
df_filtered.drop(columns=['coordinates'], inplace=True)
# Out:
# /var/folders/xl/dpqgd5313dvdp7z5kg6whtn40000gn/T/ipykernel_40956/997662286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['latitude'] = df_filtered['coordinates'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None)
# /var/folders/xl/dpqgd5313dvdp7z5kg6whtn40000gn/T/ipykernel_40956/997662286.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['longitude'] = df_filtered['coordinates'].apply(lambda x: x[1] if isinstance(x, list) and len(x) > 1 else None)
# /var/folders/xl/dpqgd5313dvdp7z5kg6whtn40000gn/T/ipykernel_40956/997662286.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop(columns=['coordinates'], inplace=True)

# %%
df_filtered
# Out:
#     station_id                               station_name  \
# 0         KGPH  Mosby Midwest National Air Center Airport
# 1         KGPH  Mosby Midwest National Air Center Airport
# 2         KGPH  Mosby Midwest National Air Center Airport
# 3         KGPH  Mosby Midwest National Air Center Airport
# 4         KGPH  Mosby Midwest National Air Center Airport
# ..         ...                                        ...
# 276       KGPH  Mosby Midwest National Air Center Airport
# 277       KGPH  Mosby Midwest National Air Center Airport
# 278       KGPH  Mosby Midwest National Air Center Airport
# 279       KGPH  Mosby Midwest National Air Center Airport
# 280       KGPH  Mosby Midwest National Air Center Airport
#
#                      timestamp  temperature_unit  wind_speed_unit  \
# 0    2025-07-07T19:55:00+00:00              31.0             7.56
# 1    2025-07-07T18:55:00+00:00              31.0            11.16
# 2    2025-07-07T17:55:00+00:00              30.0             0.00
# 3    2025-07-07T15:35:00+00:00              28.0             5.40
# 4    2025-07-07T14:55:00+00:00              28.0             0.00
# ..                         ...               ...              ...
# 276  2025-06-30T22:35:00+00:00              24.0             5.40
# 277  2025-06-30T22:15:00+00:00              23.0             5.40
# 278  2025-06-30T21:55:00+00:00              23.0             9.36
# 279  2025-06-30T21:35:00+00:00              22.0             7.56
# 280  2025-06-30T21:15:00+00:00              22.0             7.56
#
#      humidity_value  latitude  longitude
# 0         48.878892    -94.31      39.33
# 1         55.321861    -94.31      39.33
# 2         58.581385    -94.31      39.33
# 3         65.771195    -94.31      39.33
# 4         65.771195    -94.31      39.33
# ..              ...       ...        ...
# 276       78.354092    -94.31      39.33
# 277       78.209170    -94.31      39.33
# 278       78.209170    -94.31      39.33
# 279       83.107688    -94.31      39.33
# 280       88.436416    -94.31      39.33
#
# [281 rows x 8 columns]

# %% [markdown]
# ## QA

# %%
# null values
df_filtered.isnull().sum()
# Out:
# station_id          0
# station_name        0
# timestamp           0
# temperature_unit    1
# wind_speed_unit     2
# humidity_value      4
# latitude            0
# longitude           0
# dtype: int64

# %%
# max and min timestamps (to check the range)
max_timestamp = df_filtered['timestamp'].max()
min_timestamp = df_filtered['timestamp'].min()
print(f"Max timestamp: {max_timestamp}")
print(f"Min timestamp: {min_timestamp}")
# Out:
# Max timestamp: 2025-07-07T19:55:00+00:00
# Min timestamp: 2025-06-30T21:15:00+00:00
