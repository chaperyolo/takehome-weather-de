# %% [markdown]
# # Analysis preview

# %% [markdown]
# This preview helps me know what kind of data I'm moving and how should I transform it

# %% [markdown]
# ## Variables, libraries, configs

# %%
import os
import requests
import sqlite3
import pandas as pd
from dotenv import load_dotenv
from datetime import datetime, timedelta

# %%
#loading environment variables
load_dotenv() 

STATION_ID = os.getenv("STATION_ID")
API_BASE_URL = os.getenv("API_BASE_URL")
USER_AGENT = os.getenv("USER_AGENT")

# %%
# url for each endpoint
url_station = f"{API_BASE_URL}/stations/{STATION_ID}"
url_obs = f"{API_BASE_URL}/stations/{STATION_ID}/observations"

#extraction start date (last 7 days)
start_date = (datetime.now() - timedelta(days=7))
#start date format should be YYYY-MM-DDThh:mm:ssZ or YYYY-MM-DDThh:mm:ss+hh:mm
start_date_str = start_date.strftime("%Y-%m-%dT%H:%M:%SZ")

# %% [markdown]
# ## Extraction

# %% [markdown]
# ### Testing /stations endpoint

# %%
headers = {"User-Agent": USER_AGENT}
station = requests.get(url_station, headers=headers).json()

# %%
station #should handle errors (if station not found, etc)
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#   {'@version': '1.1',
#    'wx': 'https://api.weather.gov/ontology#',
#    's': 'https://schema.org/',
#    'geo': 'http://www.opengis.net/ont/geosparql#',
#    'unit': 'http://codes.wmo.int/common/unit/',
#    '@vocab': 'https://api.weather.gov/ontology#',
#    'geometry': {'@id': 's:GeoCoordinates', '@type': 'geo:wktLiteral'},
#    'city': 's:addressLocality',
#    'state': 's:addressRegion',
#    'distance': {'@id': 's:Distance', '@type': 's:QuantitativeValue'},
#    'bearing': {'@type': 's:QuantitativeValue'},
#    'value': {'@id': 's:value'},
#    'unitCode': {'@id': 's:unitCode', '@type': '@id'},
#    'forecastOffice': {'@type': '@id'},
#    'forecastGridData': {'@type': '@id'},
#    'publicZone': {'@type': '@id'},
#    'county': {'@type': '@id'}}],
#  'id': 'https://api.weather.gov/stations/KGPH',
#  'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-94.3096, 39.3325]},
#  'properties': {'@id': 'https://api.weather.gov/stations/KGPH',
#   '@type': 'wx:ObservationStation',
#   'elevation': {'unitCode': 'wmoUnit:m', 'value': 236.8296},
#   'stationIdentifier': 'KGPH',
#   'name': 'Mosby Midwest National Air Center Airport',
#   'timeZone': 'America/Chicago',
#   'forecast': 'https://api.weather.gov/zones/forecast/MOZ029',
#   'county': 'https://api.weather.gov/zones/county/MOC047',
#   'fireWeatherZone': 'https://api.weather.gov/zones/fire/MOZ029'}}

# %% [markdown]
# ### Observations endpoint

# %%
observations = requests.get(
    url_obs,
    headers=headers,
    params={"start": start_date_str}
).json()

# %%
observations
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#   {'@version': '1.1',
#    'wx': 'https://api.weather.gov/ontology#',
#    's': 'https://schema.org/',
#    'geo': 'http://www.opengis.net/ont/geosparql#',
#    'unit': 'http://codes.wmo.int/common/unit/',
#    '@vocab': 'https://api.weather.gov/ontology#',
#    'geometry': {'@id': 's:GeoCoordinates', '@type': 'geo:wktLiteral'},
#    'city': 's:addressLocality',
#    'state': 's:addressRegion',
#    'distance': {'@id': 's:Distance', '@type': 's:QuantitativeValue'},
#    'bearing': {'@type': 's:QuantitativeValue'},
#    'value': {'@id': 's:value'},
#    'unitCode': {'@id': 's:unitCode', '@type': '@id'},
#    'forecastOffice': {'@type': '@id'},
#    'forecastGridData': {'@type': '@id'},
#    'publicZone': {'@type': '@id'},
#    'county': {'@type': '@id'}}],
#  'type': 'FeatureCollection',
#  'features': [{'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T00:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T00:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T00:55:00+00:00',
#     'rawMessage': 'KGPH 070055Z AUTO 36004KT 10SM CLR 29/20 A2995 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 29,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 20,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 360,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 7.56,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101420,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 58.347168092798,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 30.784277275988888,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T00:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-07T00:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-07T00:35:00+00:00',
#     'rawMessage': 'KGPH 070035Z AUTO 01004KT 10SM CLR 30/20 A2994 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 30,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 20,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 10,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 7.56,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101390,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 55.077490108744,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 31.901506361962223,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T22:15:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T22:15:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T22:15:00+00:00',
#     'rawMessage': 'KGPH 062215Z AUTO 35008KT 10SM SCT039 SCT049 SCT060 30/20 A2994 RMK AO2',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 30,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 20,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 350,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 14.76,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101390,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 55.077490108744,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 31.901506361962223,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 1190},
#       'amount': 'SCT'},
#      {'base': {'unitCode': 'wmoUnit:m', 'value': 1490}, 'amount': 'SCT'},
#      {'base': {'unitCode': 'wmoUnit:m', 'value': 1830}, 'amount': 'SCT'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T20:15:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T20:15:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T20:15:00+00:00',
#     'rawMessage': 'KGPH 062015Z AUTO 36006KT 10SM SCT034 SCT044 30/20 A2995 RMK AO2',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 30,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 20,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 360,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 11.16,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101420,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 55.077490108744,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 31.901506361962223,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 1040},
#       'amount': 'SCT'},
#      {'base': {'unitCode': 'wmoUnit:m', 'value': 1340}, 'amount': 'SCT'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T19:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T19:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T19:35:00+00:00',
#     'rawMessage': 'KGPH 061935Z AUTO 34008KT 10SM SCT031 30/21 A2995 RMK AO2',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 30,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 340,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 14.76,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101420,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 58.581385103971,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 32.553350785335,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 940},
#       'amount': 'SCT'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T18:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T18:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T18:55:00+00:00',
#     'rawMessage': 'KGPH 061855Z AUTO 33005KT 10SM CLR 29/21 A2996 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 29,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 330,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 9.36,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101460,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 62.059071991511,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 31.35600861294111,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T18:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T18:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T18:35:00+00:00',
#     'rawMessage': 'KGPH 061835Z AUTO 32004KT 10SM CLR 29/21 A2997 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 29,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 320,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 7.56,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101490,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 62.059071991511,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 31.35600861294111,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T17:15:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T17:15:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T17:15:00+00:00',
#     'rawMessage': 'KGPH 061715Z AUTO 35009KT 10SM SCT026 SCT031 SCT046 28/21 A2998 RMK AO2',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 28,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 350,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 16.56,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101520,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 65.771194518237,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 30.12559556856,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 790},
#       'amount': 'SCT'},
#      {'base': {'unitCode': 'wmoUnit:m', 'value': 940}, 'amount': 'SCT'},
#      {'base': {'unitCode': 'wmoUnit:m', 'value': 1400}, 'amount': 'SCT'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T15:15:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T15:15:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T15:15:00+00:00',
#     'rawMessage': 'KGPH 061515Z AUTO 00000KT 10SM SCT016 27/22 A2997 RMK AO2',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 27,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 22,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101490,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 74.137240537203,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 29.208183096239445,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 490},
#       'amount': 'SCT'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T14:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T14:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T14:35:00+00:00',
#     'rawMessage': '',
#     'textDescription': '',
#     'icon': None,
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 26,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 22,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 300,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 7.56,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101490,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 78.63985107242,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 27.614217970210557,
#      'qualityControl': 'V'},
#     'cloudLayers': []}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T13:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T13:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T13:35:00+00:00',
#     'rawMessage': 'KGPH 061335Z AUTO 30003KT 10SM SCT010 26/22 A2995 RMK AO2',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/day/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 26,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 22,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 300,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 5.4,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101420,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 78.63985107242,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 27.614217970210557,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 300},
#       'amount': 'SCT'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T13:15:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T13:15:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T13:15:00+00:00',
#     'rawMessage': 'KGPH 061315Z AUTO 31003KT 10SM CLR 25/22 A2994 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/day/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 25,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 22,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 310,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 5.4,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101390,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 83.452626665984,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 25.734596362945,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T10:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T10:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T10:35:00+00:00',
#     'rawMessage': 'KGPH 061035Z AUTO 00000KT 10SM CLR 23/21 A2993 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 23,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101360,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 88.518307938961,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 23.666866929517223,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T09:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T09:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T09:55:00+00:00',
#     'rawMessage': 'KGPH 060955Z AUTO 00000KT 10SM SCT020 SCT040 23/22 A2993 RMK AO2 P0001',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 23,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 22,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101360,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': 0,
#      'qualityControl': 'C'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 94.105818040075,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 23.812763026602223,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 610},
#       'amount': 'SCT'},
#      {'base': {'unitCode': 'wmoUnit:m', 'value': 1220}, 'amount': 'SCT'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T07:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T07:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T07:35:00+00:00',
#     'rawMessage': 'KGPH 060735Z AUTO 24004KT 10SM SCT075 26/21 A2992 RMK AO2',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 26,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 240,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 7.56,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101320,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 73.970629005511,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 26.587010868477222,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 2290},
#       'amount': 'SCT'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T06:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T06:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T06:55:00+00:00',
#     'rawMessage': 'KGPH 060655Z AUTO 24003KT 10SM CLR 26/21 A2992 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 26,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 240,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 5.4,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101320,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 73.970629005511,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 26.587010868477222,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T06:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T06:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T06:35:00+00:00',
#     'rawMessage': 'KGPH 060635Z AUTO 23004KT 10SM CLR 26/21 A2992 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 26,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 230,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 7.56,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101320,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 73.970629005511,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 26.587010868477222,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T05:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T05:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T05:55:00+00:00',
#     'rawMessage': 'KGPH 060555Z AUTO 24005KT 10SM CLR 26/21 A2992 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 26,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 240,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 9.36,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101320,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 73.970629005511,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 26.587010868477222,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T04:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T04:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-07-06T04:55:00+00:00',
#     'rawMessage': 'KGPH 060455Z AUTO 18003KT 10SM CLR 26/21 A2992 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 26,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 180,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 5.4,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101320,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 73.970629005511,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 26.587010868477222,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-07-06T04:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
# ...
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101460,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 88.436416127982,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 22.564728643341667,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T05:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T05:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-06-30T05:55:00+00:00',
#     'rawMessage': 'KGPH 300555Z AUTO 00000KT 10SM CLR 22/20 A2996 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 22,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 20,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101460,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 88.436416127982,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 22.564728643341667,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T05:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T05:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-06-30T05:35:00+00:00',
#     'rawMessage': 'KGPH 300535Z AUTO 00000KT 10SM CLR 22/20 A2997 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 22,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 20,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101490,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 88.436416127982,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 22.564728643341667,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T03:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T03:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-06-30T03:55:00+00:00',
#     'rawMessage': 'KGPH 300355Z AUTO 15004KT 10SM CLR 22/20 A2996 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 22,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 20,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 150,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 7.56,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101460,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 88.436416127982,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 22.564728643341667,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T03:35:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T03:35:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-06-30T03:35:00+00:00',
#     'rawMessage': 'KGPH 300335Z AUTO 00000KT 10SM CLR 22/21 A2996 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 22,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101460,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 94.06252427588,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 22.711632578314443,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T01:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T01:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-06-30T01:55:00+00:00',
#     'rawMessage': 'KGPH 300155Z AUTO 00000KT 10SM CLR 24/21 A2992 RMK AO2',
#     'textDescription': 'Clear',
#     'icon': 'https://api.weather.gov/icons/land/night/skc?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 24,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 21,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101320,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 83.338787521304,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 24.631623896389446,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': None},
#       'amount': 'CLR'}]}},
#   {'id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T00:55:00+00:00',
#    'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-94.31, 39.33]},
#    'properties': {'@id': 'https://api.weather.gov/stations/KGPH/observations/2025-06-30T00:55:00+00:00',
#     '@type': 'wx:ObservationStation',
#     'elevation': {'unitCode': 'wmoUnit:m', 'value': 237},
#     'station': 'https://api.weather.gov/stations/KGPH',
#     'stationId': 'KGPH',
#     'stationName': 'Mosby Midwest National Air Center Airport',
#     'timestamp': '2025-06-30T00:55:00+00:00',
#     'rawMessage': 'KGPH 300055Z AUTO 00000KT 10SM SCT019 26/20 A2990 RMK AO2',
#     'textDescription': 'Partly Cloudy',
#     'icon': 'https://api.weather.gov/icons/land/night/sct?size=medium',
#     'presentWeather': [],
#     'temperature': {'unitCode': 'wmoUnit:degC',
#      'value': 26,
#      'qualityControl': 'V'},
#     'dewpoint': {'unitCode': 'wmoUnit:degC',
#      'value': 20,
#      'qualityControl': 'V'},
#     'windDirection': {'unitCode': 'wmoUnit:degree_(angle)',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windSpeed': {'unitCode': 'wmoUnit:km_h-1',
#      'value': 0,
#      'qualityControl': 'V'},
#     'windGust': {'unitCode': 'wmoUnit:km_h-1',
#      'value': None,
#      'qualityControl': 'Z'},
#     'barometricPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': 101250,
#      'qualityControl': 'V'},
#     'seaLevelPressure': {'unitCode': 'wmoUnit:Pa',
#      'value': None,
#      'qualityControl': 'Z'},
#     'visibility': {'unitCode': 'wmoUnit:m',
#      'value': 16090,
#      'qualityControl': 'C'},
#     'maxTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'minTemperatureLast24Hours': {'unitCode': 'wmoUnit:degC', 'value': None},
#     'precipitationLastHour': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast3Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'precipitationLast6Hours': {'unitCode': 'wmoUnit:mm',
#      'value': None,
#      'qualityControl': 'Z'},
#     'relativeHumidity': {'unitCode': 'wmoUnit:percent',
#      'value': 69.54626593683,
#      'qualityControl': 'V'},
#     'windChill': {'unitCode': 'wmoUnit:degC',
#      'value': None,
#      'qualityControl': 'V'},
#     'heatIndex': {'unitCode': 'wmoUnit:degC',
#      'value': 26.471485832795,
#      'qualityControl': 'V'},
#     'cloudLayers': [{'base': {'unitCode': 'wmoUnit:m', 'value': 580},
#       'amount': 'SCT'}]}}]}
